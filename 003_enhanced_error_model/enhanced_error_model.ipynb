# %%
import numpy as np
import matplotlib.pyplot as plt

import cuqi
from cuqi.testproblem import Deconvolution1D, Deconvolution2D
from cuqi.distribution import JointDistribution, Gaussian, CMRF, LMRF, GMRF
from cuqi.sampler import LinearRTO, pCN, CWMH, ULA, MALA, NUTS
from cuqi.problem import BayesianProblem
from cuqi.model import LinearModel
from cuqi.data import p_power

# %%
# Set seed
np.random.seed(0)

# %%
print("cuqi version: ", cuqi.__version__)
# Out:
# cuqi version:  0.7.0

# %% [markdown]
# <h1><center>Model Error Quantification of Inverse Problem</center></h1>
# By Puyuan Mi
#
# # Problem Settings
#
# ## 2D Convolution
# 2D Deconvolution concerns the following linear inverse problem
# \begin{equation}
# y_{data}=Ax_{exact}+e
# \end{equation}
# Where $A$ is some PSF operator, $x_{exact}$ is the exact image, $y_{data}$ is the blurred image, and $e$ is some white noise. Sometimes it's tricky to get the explicit $A$, while an approximated convolution operator $\tilde{A}$ would introduce the model discrepancy. The problem concerning the model error is like
# \begin{equation}
# y_{data}=\tilde{A}x_{exact}+m+e,\ s.t.\ m = (A-\tilde{A})x_{exact}
# \end{equation}
# $m$ could be crutial but hard to formulate under Bayes' formula, and the enhanced error model would alleviate challenges.
#
# In this test problem, we take $x_{exact}$ as the p-power class phantom from the cuqi.data. It is an image generated from a random pattern of nonzero pixels with correlation between pixels. We take $F$ as a Gaussian blur from cuqi.testproblem.

# %%
# Load forward model, data and problem information
phantom = p_power(relnz=1)
F, y_data, probInfo = Deconvolution2D(phantom=phantom, dim=64, BC = 'zero').get_components()

# For convenience, we define the dimension of the domain of A
n = F.domain_dim
m = F.range_dim

M_exact = None
if 0:
    # PSF matrix
    M_exact = F.get_matrix()

# For convenience, we extract the exact solution as x_exact
x_exact = probInfo.exactSolution
print(x_exact.geometry)
F@x_exact

# Plot the data
plt.figure()
x_exact.plot(); plt.title('Exact Solution'); 
plt.figure()
y_data.plot(); plt.title('Data')
plt.show()

# Print information about the problem
print(probInfo)
# Out:
# Image2D(4096,)
# ProblemInfo with the following set attributes:
# ['infoString', 'Miscellaneous', 'exactData', 'exactSolution']
#  infoString: Noise type: Additive Gaussian with std: 0.0036
#  Miscellaneous: dict_keys(['PSF', 'BC'])

# %% [markdown]
# We take $f$ as an out-of-focus blur from cuqi.testproblem.

# %%
# Load approximated forward model
f = Deconvolution2D(PSF = "Defocus", dim=64, BC = 'zero').get_components()[0]

if M_exact is not None:
    # model discrepency
    M_f = f.get_matrix()
    M_d = M_exact-M_f
    fig = plt.imshow(M_d.toarray())
    plt.colorbar(fig)
    plt.show()

# %% [markdown]
# We define the prior $x \sim GMRF(x_0, \Gamma_x)$, which could be a good illustration of the p-power class phantom as the correlation only exists significantly in the neighbourhood of any pixel.

# %%
# prior mean
x_mean = 0.5*np.ones(n)

# prior precision
x_perc = 100

# prior
x = GMRF(mean=x_mean, prec = x_perc, physical_dim=2, bc_type = "zero", order=2)
# Sampling not implemented for zero boundary conditions in 2D
print(x.geometry)

# prior instance
x.sample(1).plot()
# Out:
# Image2D(4096,)

# %% [markdown]
# We take the noise $e \sim Gaussian(e_0, \Gamma_e)$ for the white noise.

# %%
# noise mean
e_mean = np.zeros(m)

# noise cov
e_cov = 0.0001

# %% [markdown]
# The enhanced error model (EEM, or AEM as the approximated error model) concerns the model error in the formulation of the likelihood. It assumes that $m$ is independent from $x$ with Gaussian distribution of mean $m_0$ and covariance $\Gamma_m$. Moreover, Given prior samples $X_i^0 \sim \pi(x), i=1,...,N$, $m_0^1$ and $\Gamma_m^1$ are approximated upon samples of the model error $M_i^1 = (A-\tilde{A})X_i^0$ as
# \begin{equation}
# m_0^1 \approx mean(M_i),\ \Gamma_m^1 \approx cov(M_i).
# \end{equation}
# Introducing $v^1 = m^1 + e$, then $v^1$ is also independent from $x$ with Gaussian distribution with mean $v_0^1 = m_0^1$
# and covariance $\Gamma_v^1 = \Gamma_m^1 + \Gamma_e$. The corresponding likelihood is like
# \begin{equation}
# L_{EEM}^1(x|y=y_{data}) = Gaussian(\tilde{A}x+v_0^1, \Gamma_v^1)
# \end{equation}

# %%
# sample the model error

def AEM_forward_sampler(F, f, xs, sampleN):
    # Get samples of the model error    
    ms = (F@xs).samples - (f@xs).samples
    m_mean = np.mean(ms, axis=1)
    m_cov = np.cov(ms)

    return m_mean, m_cov

sampleN = 1000
# prior sampling
xs = x.sample(sampleN)
m_mean, m_cov = AEM_forward_sampler(F, f, xs, sampleN)

# likelihood
y = Gaussian(f@x, e_cov+m_cov)

# %% [markdown]
# Now we could define the posterior under Bayes' formula as
# \begin{equation}
# P_{EEM}^1(x|y=y_{data}) \propto L_{EEM}^1(x|y=y_{data})Pr(x)
# \end{equation}

# %%
# Define posterior
post_EEM = BayesianProblem(y, x).set_data(y=y_data-m_mean)
print(post_EEM)
# Out:
# BayesianProblem with target:
#  Posterior(
#     Equation:
# 	 p(x|y) ∝ L(x|y)p(x)
#     Densities:
# 	y ~ CUQI Gaussian Likelihood function. Parameters ['x'].
#  	x ~ CUQI GMRF.
#  )

# %% [markdown]
# We sample the posterior with linear RTO.

# %%
# Linear RTO sampling
samples_EEM = post_EEM.sample_posterior(sampleN)

# sample mean
mean_EEM = samples_EEM.mean()
# Out:
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!! Automatic sampler selection is experimental. !!!
# !!!    Always validate the computed results.     !!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Using LinearRTO sampler.
# burn-in: 20%
# Sample 1200 / 1200
# Elapsed time: 214.88085746765137

# %% [markdown]
# We show UQ results.

# %%
# UQ result
samples_EEM.plot_ci()
# Out:
# [<matplotlib.image.AxesImage at 0x7f8dd8931b20>,
#  None,
#  <matplotlib.image.AxesImage at 0x7f8dd882e4f0>,
#  <matplotlib.image.AxesImage at 0x7f8dd88e8ac0>,
#  <matplotlib.image.AxesImage at 0x7f8dd88ae4c0>]

# %% [markdown]
# To do comparison, we also need to formulate the reference posterior $P_{A}$ and the posterior concerning no model error $P_{\tilde{A}}$. Posteriors are
# \begin{equation}
# P_{A}(x|y=y_{data}) \propto L_{A}(x|y=y_{data})Pr(x),\ s.t.\ L_{A}(x|y=y_{data}) = Gaussian(Ax, \Gamma_e)
# \end{equation}
# and
# \begin{equation}
# P_{\tilde{A}}(x|y=y_{data}) \propto L_{\tilde{A}}(x|y=y_{data})Pr(x),\ s.t.\ L_{\tilde{A}}(x|y=y_{data}) = Gaussian(\tilde{A}x, \Gamma_e)
# \end{equation}
# respectively.

# %%
# Reference

# likelihood
y_F = Gaussian(F@x, 0.0036**2)

# posterior
post_F = BayesianProblem(y_F, x).set_data(y_F=y_data)

# sampling
samples_F = post_F.sample_posterior(sampleN)

# UQ result
samples_F.plot_ci()

# sample mean
mean_F = samples_F.mean()
# Out:
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!! Automatic sampler selection is experimental. !!!
# !!!    Always validate the computed results.     !!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Using LinearRTO sampler.
# burn-in: 20%
# Sample 1200 / 1200
# Elapsed time: 33.247252225875854

# %%
# likelihood
y_f = Gaussian(f@x, 0.0036**2)

# posterior
post_f = BayesianProblem(y_f, x).set_data(y_f=y_data)

# sampling
samples_f = post_f.sample_posterior(sampleN)

# UQ result
samples_f.plot_ci()

# sample mean
mean_f = samples_f.mean()
# Out:
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!! Automatic sampler selection is experimental. !!!
# !!!    Always validate the computed results.     !!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Using LinearRTO sampler.
# burn-in: 20%
# Sample 1200 / 1200
# Elapsed time: 33.04028606414795

# %% [markdown]
# We compare the relative error of the posterior mean of $P_{EEM}$ and $P_{\tilde{A}}$ with $P_A$.

# %%
# comparison on sample mean
print(f"re without model error = {np.linalg.norm(mean_f-mean_F)/np.linalg.norm(mean_F)}")
print(f"re with model error = {np.linalg.norm(mean_EEM-mean_F)/np.linalg.norm(mean_F)}")
# Out:
# re without model error = 0.23979327307006654
# re with model error = 0.15230066434356848

# %% [markdown]
# The iterative updated error model (IUEM) iteratively updates the model error and the corresponding posterior in order to get a better posterior estimate. More percisely, after getting $P_{EEM}$, IUEM draws samples $X_i^1 \sim P_{EEM}$ and updates model error samples as $M_i^2 = (A-\tilde{A})X_i^1$. The posterior is correspondingly updated and the process is iterated as
# \begin{equation}
# M_i^{k+1} = (A-\tilde{A})X_i^k, \ P_{EEM}^{k+1}(x|y=y_{data}) \propto L_{EEM}^{k+1}(x|y=y_{data})Pr(x)
# \end{equation}
# where
# \begin{equation}
# L_{EEM}^{k+1}(x|y=y_{data}) = Gaussian(\tilde{A}x+v_0^{k+1}, \Gamma_v^{k+1})
# \end{equation}
# with $v_0^{k+1} = mean(M_i^{k+1})$ and $\Gamma_v^{k+1} = cov(M_i^{k+1})+\Gamma_e$
# until the posterior gets stable.

# %%
# total iterations
iterations = 10
res = []
for k in range(1, iterations):
    # model error
    m_mean, m_cov = AEM_forward_sampler(F, f, samples_EEM, sampleN)
    # likelihood
    y = Gaussian(f@x, e_cov+m_cov)
    # posterior
    post_EEM = BayesianProblem(y, x).set_data(y=y_data-m_mean)
    # sampling
    samples_EEM = post_EEM.sample_posterior(sampleN)
    # sample mean
    mean_EEM = samples_EEM.mean()
    # UQ result
    cuqi.array.CUQIarray(mean_EEM, geometry=F.domain_geometry).plot()
    plt.show()
    # comparison on sample mean
    re = np.linalg.norm(mean_EEM-mean_F)/np.linalg.norm(mean_F)
    res.append(re)
    print(f"re of {k+1}th iteration IUEM = {re}")
# Out:
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!! Automatic sampler selection is experimental. !!!
# !!!    Always validate the computed results.     !!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Using LinearRTO sampler.
# burn-in: 20%
# Sample 1200 / 1200
# Elapsed time: 239.41642355918884
# re of 2th iteration IUEM = 0.0818052448618793
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!! Automatic sampler selection is experimental. !!!
# !!!    Always validate the computed results.     !!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Using LinearRTO sampler.
# burn-in: 20%
# Sample 1200 / 1200
# Elapsed time: 232.73960280418396
# re of 3th iteration IUEM = 0.06367188712734453
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!! Automatic sampler selection is experimental. !!!
# !!!    Always validate the computed results.     !!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Using LinearRTO sampler.
# burn-in: 20%
# Sample 1200 / 1200
# Elapsed time: 231.05842089653015
# re of 4th iteration IUEM = 0.05587021709033945
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!! Automatic sampler selection is experimental. !!!
# !!!    Always validate the computed results.     !!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Using LinearRTO sampler.
# burn-in: 20%
# Sample 1200 / 1200
# Elapsed time: 232.74307560920715
# re of 5th iteration IUEM = 0.049926205690751506
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!! Automatic sampler selection is experimental. !!!
# !!!    Always validate the computed results.     !!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Using LinearRTO sampler.
# burn-in: 20%
# Sample 1200 / 1200
# Elapsed time: 253.96836614608765
# re of 6th iteration IUEM = 0.0456481370934495
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!! Automatic sampler selection is experimental. !!!
# !!!    Always validate the computed results.     !!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Using LinearRTO sampler.
# burn-in: 20%
# Sample 1200 / 1200
# Elapsed time: 249.8470573425293
# re of 7th iteration IUEM = 0.04264854157029194
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!! Automatic sampler selection is experimental. !!!
# !!!    Always validate the computed results.     !!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Using LinearRTO sampler.
# burn-in: 20%
# Sample 1200 / 1200
# Elapsed time: 238.2101593017578
# re of 8th iteration IUEM = 0.04153892504311259
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!! Automatic sampler selection is experimental. !!!
# !!!    Always validate the computed results.     !!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Using LinearRTO sampler.
# burn-in: 20%
# Sample 1200 / 1200
# Elapsed time: 210.13398241996765
# re of 9th iteration IUEM = 0.03992815995544759
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!! Automatic sampler selection is experimental. !!!
# !!!    Always validate the computed results.     !!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Using LinearRTO sampler.
# burn-in: 20%
# Sample 1200 / 1200
# Elapsed time: 217.43624329566956
# re of 10th iteration IUEM = 0.0392937107261768

# %% [markdown]
# We plot the relative error of the posterior mean comparing to that of $P_A$ w.r.t iterations.

# %%
plt.figure()
xlim = np.arange(1,10)
plt.plot(xlim, res, label='IUEM')
plt.plot(xlim, res[0]*np.ones(iterations-1), '--', label='EEM')
plt.plot(xlim, np.linalg.norm(mean_f-mean_F)/np.linalg.norm(mean_F)*np.ones(iterations-1), '--', label='without model error')
plt.legend()
plt.show()
